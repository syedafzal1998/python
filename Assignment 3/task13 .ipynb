# %%
print("Python Calculator Generated By Muhammad Zubair Minhas")
l=0
while l<1:
    print("\n1 Addition\n2 Subtration\n3 Multiplication\n4 Division\n5 Power")
    a=int(input("Enter Choice:"))
    if a==1:
        print("Your Choice Is Addition")
        n1=int(input("Enter First Number :"))
        n2=int(input("Enter Second Number :"))
        sum =n1+n2
        print(f"The Sum Of {n1} and {n2} is :{sum}")
        
    if a==2:
        print("Your Choice Is Subtration")
        n1=int(input("Enter First Number :"))
        n2=int(input("Enter Second Number :"))
        sub =n1-n2
        print(f"The Sub Of {n1} and {n2} is :{sub}")
        
    if a==3:
        print("Your Choice Is Multiplication")
        n1=int(input("Enter First Number :"))
        n2=int(input("Enter Second Number :"))
        multi =n1*n2
        print(f"The Multiplication Of {n1} and {n2} is :{multi}")
    if a==4:
        print("Your Choice Is Division")
        n1=int(input("Enter First Number :"))
        n2=int(input("Enter Second Number :"))
        divide =n1/n2
        print(f"The Division Of {n1} and {n2} is :{divide}")
        
    if a==5:
        print("Your Choice Is Power")
        n1=int(input("Enter First Number :"))
        n2=int(input("Enter Second Number :"))
        power =n1**n2
        print(f"The Power Of {n1} and {n2} is :{power}")
        
    
    
    
    l=int(input("If Continue to Enter '0' other wise enter other number : "))
# Out:
# Python Calculator Generated By Muhammad Zubair Minhas
#
# 1 Addition
# 2 Subtration
# 3 Multiplication
# 4 Division
# 5 Power
# Enter Choice:1
# Your Choice Is Addition
# Enter First Number :23
# Enter Second Number :45
# The Sum Of 23 and 45 is :68
# If Continue to Enter '0' other wise enter other number : 0
#
# 1 Addition
# 2 Subtration
# 3 Multiplication
# 4 Division
# 5 Power
# Enter Choice:2
# Your Choice Is Subtration
# Enter First Number :10
# Enter Second Number :3
# The Sub Of 10 and 3 is :7
# If Continue to Enter '0' other wise enter other number : 0
#
# 1 Addition
# 2 Subtration
# 3 Multiplication
# 4 Division
# 5 Power
# Enter Choice:3
# Your Choice Is Multiplication
# Enter First Number :3
# Enter Second Number :4
# The Multiplication Of 3 and 4 is :12
# If Continue to Enter '0' other wise enter other number : 0
#
# 1 Addition
# 2 Subtration
# 3 Multiplication
# 4 Division
# 5 Power
# Enter Choice:4
# Your Choice Is Division
# Enter First Number :25
# ...
